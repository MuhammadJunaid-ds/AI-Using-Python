# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X, Y = make_classification(
    n_samples=1000,
    n_features=100,
    n_informative=10,
    n_redundant=40,
    random_state=42,
    n_repeated=10
)

x_train, x_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.3, stratify=Y, random_state=42
)

print('Original feature Dimention: ',X.shape[1])
# Out:
# Original feature Dimention:  100

# %%
svm_baseline = SVC(kernel='rbf', C=10)
svm_baseline.fit(x_train, y_train)
pred_base = svm_baseline.predict(x_test)
acc_base = accuracy_score(y_test, pred_base)
print(f'SVM Accuracy at C=10 : {acc_base:.4f}')
# Out:
# SVM Accuracy at C=10 : 0.9533

# %%
svm_reg = SVC(kernel='rbf', C=1)
svm_reg.fit(x_train, y_train)
pred_reg = svm_reg.predict(x_test)
acc_reg = accuracy_score(y_test, pred_reg)
print(f'SVM Accuracy at C=1 : {acc_reg:.4f}')
# Out:
# SVM Accuracy at C=1 : 0.9600

# %%
pca = PCA(n_components=20)
x_train_pca = pca.fit_transform(x_train)
x_test_pca = pca.transform(x_test)

svm_pca = SVC(kernel='rbf', C=1)
svm_pca.fit(x_train_pca, y_train)
pred_pca = svm_pca.predict(x_test_pca)
acc_pca = accuracy_score(y_test, pred_pca)
print(f'SVM Accuracy for PCA: {acc_pca}')
# Out:
# SVM Accuracy for PCA: 0.96

# %%
select = SelectKBest(score_func=f_classif, k=20)
x_train_sel = pca.fit_transform(x_train)
x_test_sel = pca.transform(x_test)

svm_sel = SVC(kernel='rbf', C=1)
svm_sel.fit(x_train_sel, y_train)
pred_sel = svm_sel.predict(x_test_sel)
acc_sel = accuracy_score(y_test, pred_sel)
print(f'SVM Accuracy for PCA: {acc_sel}')
# Out:
# SVM Accuracy for PCA: 0.96

# %%
print(f'BaseLine SVM: {acc_base:.3f}')
print(f'Regularized SVM: {acc_reg:.3f}')
print(f'SVM + PCA (20 imp Components): ',acc_pca)
print('SVN + SELECTION (20): ',acc_sel)
# Out:
# BaseLine SVM: 0.953
# Regularized SVM: 0.960
# SVM + PCA (20 imp Components):  0.96
# SVN + SELECTION (20):  0.96
